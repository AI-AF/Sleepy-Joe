# %%
import datetime
import sys

sys.path.append('../src/')

# %%
import gringotts
import config

# %%
curr_token = gringotts.load_token('73DJXK')

# %%
curr_token
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMkJHMkQiLCJzdWIiOiI3M0RKWEsiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJzZXQgcmFjdCBybG9jIHJ3ZWkgcmhyIHJudXQgcnBybyByc2xlIiwiZXhwIjoxNTgzMTI1Njg3LCJpYXQiOjE1ODMwOTY4ODd9.oYH97aG9wn1RCBCO09o585NqwVpROscySUy2IOOwSjw',
#  'expires_in': 28800,
#  'refresh_token': '68dd5572eb87f2b52209b86ae580cba7127a5dcab2dd589c24466761c5a79f7e',
#  'scope': ['sleep',
#   'social',
#   'nutrition',
#   'settings',
#   'weight',
#   'location',
#   'profile',
#   'activity',
#   'heartrate'],
#  'token_type': 'Bearer',
#  'user_id': '73DJXK',
#  'expires_at': 1583125687.7073941}

# %%
import fitbit

# %%
ruben_client = fitbit.Fitbit(
    client_id = config.JOE_ID,
    client_secret = config.JOE_SHH,
    access_token = curr_token['access_token'],
    refresh_token = curr_token['refresh_token'],
    expires_at = curr_token['expires_at'],
    refresh_cb = gringotts.save_token,
)

# %%
ruben_client.API_VERSION
# Out:
# 1.2

# %%
test = ruben_client.get_badges()
# Out:
# SAVING TOKEN
# =====
#
# TOKEN SAVED TO /Users/rubenflamshepherd/projects/Sleepy-Joe/src/tokens/73DJXK_token.pkl
# =====

# %%
test
# Out:
# {'badges': [{'badgeGradientEndColor': '00D3D6',
#    'badgeGradientStartColor': '007273',
#    'badgeType': 'DAILY_STEPS',
#    'category': 'Daily Steps',
#    'cheers': [],
#    'dateTime': '2019-09-02',
#    'description': '30,000 steps in a day',
#    'earnedMessage': 'Congrats on earning your first Trail Shoe badge!',
#    'encodedId': '228TM5',
#    'image100px': 'https://static0.fitbit.com/images/badges_new/100px/badge_daily_steps30k.png',
#    'image125px': 'https://static0.fitbit.com/images/badges_new/125px/badge_daily_steps30k.png',
#    'image300px': 'https://static0.fitbit.com/images/badges_new/300px/badge_daily_steps30k.png',
#    'image50px': 'https://static0.fitbit.com/images/badges_new/badge_daily_steps30k.png',
#    'image75px': 'https://static0.fitbit.com/images/badges_new/75px/badge_daily_steps30k.png',
#    'marketingDescription': "You've walked 30,000 steps  And earned the Trail Shoe badge!",
# ...

# %%
test = ruben_client.get_sleep(
    datetime.date(2020, 2, 28),
)

# %%
test
# Out:
# {'sleep': [{'dateOfSleep': '2020-02-28',
#    'duration': 17940000,
#    'efficiency': 93,
#    'endTime': '2020-02-28T06:07:00.000',
#    'infoCode': 0,
#    'isMainSleep': True,
#    'levels': {'data': [{'dateTime': '2020-02-28T01:08:00.000',
#       'level': 'wake',
#       'seconds': 30},
#      {'dateTime': '2020-02-28T01:08:30.000', 'level': 'light', 'seconds': 270},
#      {'dateTime': '2020-02-28T01:13:00.000', 'level': 'wake', 'seconds': 1470},
#      {'dateTime': '2020-02-28T01:37:30.000', 'level': 'light', 'seconds': 150},
#      {'dateTime': '2020-02-28T01:40:00.000', 'level': 'wake', 'seconds': 660},
#      {'dateTime': '2020-02-28T01:51:00.000',
#       'level': 'light',
#       'seconds': 1200},
#      {'dateTime': '2020-02-28T02:11:00.000', 'level': 'deep', 'seconds': 660},
#      {'dateTime': '2020-02-28T02:22:00.000',
#       'level': 'light',
#       'seconds': 2430},
#      {'dateTime': '2020-02-28T03:02:30.000', 'level': 'wake', 'seconds': 300},
# ...
